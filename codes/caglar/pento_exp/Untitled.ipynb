# %%
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import cPickle as  pkl
# %matplotlib inline

# %%
stats = pkl.load(open("/u/gulcehrc/Experiments/codes/python/MemoryNetwork/codes/caglar/pento_exp/tests/pento_mainloop_nohints2_stats.pkl"))

# %%
plt.plot(stats['Train_full_costs'])

# %%
plt.plot(stats['Valid_full_costs'])

# %%
plt.plot(stats['Valid_full_errors'])

# %%
plt.plot(stats['Train_full_errors'])

# %%
plt.plot(stats['norm_up'])

# %%
plt.plot(stats['param_norm'])
